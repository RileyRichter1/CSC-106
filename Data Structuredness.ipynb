# %% [markdown]
# # Group Exercise

# %% [markdown]
# # Types of Data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Structured Data

# %% [raw]
# Meta-data (Time and date of creation, File size, Author etc.)
# Library Catalogues (date, author, place, subject, etc)
# Census records (birth, income, employment, place etc.)
# Economic data (GDP, PPI, ASX etc.)
# FaceBook like button
# Phone numbers (and the phone book)
# Databases (structuring fields)

# %% [raw]
# Unstructured Data

# %% [raw]
# Text files (Word processing, spreadsheets, presentations etc.)
# Email body
# Social Media ( Data from Facebook, Twitter, LinkedIn)
# Website (YouTube, Instagram, photo sharing sites )
# Mobile data ( Text messages )
# Communications ( Chat, IM, phone recordings, collaboration software )
# Media ( MP3, digital photos, audio and video files )

# %% [markdown]
# # Container in Container

# %% [markdown]
# # Tuple Family

# %% [raw]
# # Tuple in Tuple

# %%
TinT = (2, 4, (8, 7, 30), 6, 220, 10, 77, 54)

# %% [markdown]
# Exercise : What is the data type?
# tuple

# %%
type(TinT)
# Out:
# tuple

# %% [markdown]
# Exercise : What is the len of the data type?

# %%
len(TinT)
# Out:
# 8

# %% [markdown]
# Exercise : How do we access elements?

# %%
#Print 1st item in tuple
print(TinT[0])
#Print 2nd item in the tuple's tuple
print(TinT[2][1])
# Out:
# 2
# 7

# %% [markdown]
# Explore : Can we Insert, Update or Delete?

# %% [markdown]
# No

# %% [raw]
# # List in Tuple

# %%
LinT = (2, 4, [8, 7, 30], 6, 220, 10, 77, 54)

# %% [markdown]
# Exercise : What is the data type?

# %%
type(LinT)
# Out:
# tuple

# %% [markdown]
# Exercise : What is the len of the data type?

# %%
len(LinT)
# Out:
# 8

# %% [markdown]
# Exercise : How do we access elements?

# %%
#Print 1st item in tuple
print(LinT[0])
#Print 2nd item in the tuple's list
print(LinT[2][1])
# Out:
# 2
# 7

# %% [markdown]
# Explore : Can we Insert, Update or Delete?

# %% [markdown]
# No

# %% [raw]
# # Dictionary in Tuple

# %%
DinT = (2, 4, {"Name":"Python"}, 6, 220, 10, 77, 54)

# %% [markdown]
# Exercise : What is the data type?

# %%
type(DinT)
# Out:
# tuple

# %% [markdown]
# Exercise : What is the len of the data type?

# %%
len(DinT)
# Out:
# 8

# %% [markdown]
# Exercise : How do we access elements?

# %%
#Print 1st item in tuple
print(DinT[0])
#Print Name in the tuple's dictionary
print(DinT[2]["Name"])
# Out:
# 2
# Python

# %% [markdown]
# Explore : Can we Insert, Update or Delete?

# %% [markdown]
# No

# %% [markdown]
# # List Family

# %% [raw]
# List in List

# %%
LinL1 = [1, 2, 3, 4, [4.5, 4.8], 5, 6, 7]
print(LinL1)
# Out:
# [1, 2, 3, 4, [4.5, 4.8], 5, 6, 7]

# %% [raw]
# Tuple in List

# %%
TinL1 = [1, 2, 3, (3.3, 3.4), 4, 5]
print(TinL1)
# Out:
# [1, 2, 3, (3.3, 3.4), 4, 5]

# %% [raw]
# Dictionary in List

# %%
DinL1 = [1, 2, 3, 4, {"Name": "Riley"}, 5, 6]
print(DinL1)
# Out:
# [1, 2, 3, 4, {'Name': 'Riley'}, 5, 6]

# %% [markdown]
# # Dictionary Family

# %% [raw]
# Dictionary in Dictionary

# %%
DinD1 = {
    "Full Name": {"Fname": "Riley", "Lname": "Richter"},
    "Email": "rjrichter1@umary.edu"
}
print(DinD1)
# Out:
# {'Full Name': {'Fname': 'Riley', 'Lname': 'Richter'}, 'Email': 'rjrichter1@umary.edu'}

# %% [raw]
# Tuple in Dictionary

# %%
TinD1 = {
    "Tuple": (0, 1, 2),
    "Int": 1
}
print(TinD1)
# Out:
# {'Tuple': (0, 1, 2), 'Int': 1}

# %% [raw]
# List in Dictionary

# %%
LinD1 = {
    "List": [0, 1, 2],
    "Int": 1
}
print(LinD1)
# Out:
# {'List': [0, 1, 2], 'Int': 1}

# %% [markdown]
# # Submission

# %% [raw]
# Name of group members :
#
# 1. Ryan Larson
# 2. Brady Colbert
# 3. Riley Richter
# 4.
#
# Email to sbatukdeo@umary.edu
